# %% [markdown]
# # correlation with target in train

# %%
import csv
import matplotlib.pyplot as plt
import pandas as pd

from IPython.display import display
from matplotlib.backends.backend_pdf import PdfPages

# %matplotlib inline

# %%
df_train = pd.read_csv('../data/input_data.HS.csv')
cols = [col for col in df_train.columns if col not in {'disease', 'source', 'hg19_pos(1-based)'}]
df_train = df_train[cols]

# %%
target = df_train.pop('target')
corr = df_train._get_numeric_data().corrwith(target)

# %%
fig = plt.figure(figsize=(10,25))
ax = fig.add_subplot(111)
#plt.figure()
corr.plot(kind='barh', ax = ax, fontsize=15)
ax.set_xlim(-0.4,0.7)
title='correlation with target in HS training data'
ax.set_title(title,fontsize= 20) 

fig.savefig("HS_corr.pdf", bbox_inches='tight')

# %% [markdown]
# # mvp dist HIS and HS separately, in training, testing, cancer, largeset de novo mutation dataset.

# %%
df.columns
# Out:
# Index([u'MutationAssessor_score_rankscore', u'VEST3_rankscore',
#        u'Polyphen2_HDIV_rankscore', u'Polyphen2_HVAR_rankscore',
#        u'SIFT_converted_rankscore', u'PROVEAN_converted_rankscore',
#        u'MetaSVM_rankscore', u'MetaLR_rankscore',
#        u'FATHMM_converted_rankscore', u'M-CAP_rankscore',
#        u'GenoCanyon_score_rankscore', u'LRT_converted_rankscore',
#        u'Eigen-PC-raw_rankscore', u'Eigen-phred', u'Eigen-PC-phred',
#        u'DANN_rankscore', u'CADD_phred', u'CADD_raw_rankscore',
#        u'phyloP20way_mammalian_rankscore', u'GERP++_RS_rankscore',
#        u'SiPhy_29way_logOdds_rankscore',
#        u'phastCons100way_vertebrate_rankscore', u'fathmm-MKL_coding_rankscore',
#        u'phyloP100way_vertebrate_rankscore',
#        u'MutationTaster_converted_rankscore',
#        u'phastCons20way_mammalian_rankscore',
#        u'GM12878_fitCons_score_rankscore', u'HUVEC_fitCons_score_rankscore',
#        u'integrated_fitCons_score_rankscore',
#        u'H1-hESC_fitCons_score_rankscore', u'blosum62', u'pam250',
#        u'SUMO_diff', u'SUMO_score', u'SUMO_cutoff', u'phospho_cutoff',
#        u'phospho_score', u'phospho_diff', u'lofz', u'prec', u'pli', u's_het',
#        u's_het_log', u'secondary_E', u'secondary_H', u'complex_CORUM',
#        u'preppi_counts', u'1000Gp3_AF', u'ExAC_AF', u'gnomad', u'ASA',
#        u'secondary_C', u'gc_content', u'interface', u'ubiquitination',
#        u'BioPlex', u'target', u'hg19_chr', u'hg19_pos(1-based)', u'ref',
#        u'alt', u'category', u'source', u'INFO', u'disease', u'genename'],
#       dtype='object')

# %%
fins = ['../data/input_data.HIS.cnn.csv','../data/input_data.HS.cnn.csv',
'../data/case_control/case_MarkDaly.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv',
'../data/case_control/chd_yale.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv',
'../data/case_control/control_MarkDaly.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv',
'../data/case_control/DDD_new_0.2.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv',
'../data/case_control/case_MarkDaly.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv',
'../data/case_control/chd_yale.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv',
'../data/case_control/control_MarkDaly.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv',
'../data/case_control/DDD_new_0.2.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv',
'../data/cancer_hotspots/cancer_sel.HIS.reformat.cnn.csvAnn.mpc.csv',
'../data/cancer_hotspots/cancer_sel.HS.reformat.cnn.csvAnn.mpc.csv',
'../data/metaSVM/metaSVM_addtest1.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv',
'../data/metaSVM/metaSVM_addtest1.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv',
'../data/metaSVM/metaSVM_addtest2.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv',
'../data/metaSVM/metaSVM_addtest2.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv',
'../data/metaSVM/metaSVM_test1.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv',
'../data/metaSVM/metaSVM_test1.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv',
'../data/metaSVM/metaSVM_test2.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv',
'../data/metaSVM/metaSVM_test2.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv',
'../data/metaSVM/metaSVM_test3.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv',
'../data/metaSVM/metaSVM_test3.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv',
'../data/metaSVM/metaSVM_train.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv',
'../data/metaSVM/metaSVM_train.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv']

col = 'cnn_prob'#'cnn_prob' #'pli'
for fin in fins:
    print fin
    
    df = pd.read_csv(fin)
    title = fin.split('/')[-1].split('.')[0]
    
    
    df_pos = df[df.target==1]
    df_neg = df[df.target==0]
    if '.HIS.' in fin:
        title = 'HIS-' + title + '\npos:{}, neg:{}'.format(df_pos.shape[0], df_neg.shape[0])
    elif '.HS.' in fin:
        title = 'HS-' + title + '\npos:{}, neg:{}'.format(df_pos.shape[0], df_neg.shape[0])
    
    fig, axs = plt.subplots()
    df_neg.hist(col, bins = 100, ax = axs, color = 'blue', label = 'benign')
    df_pos.hist(col, bins = 100, ax = axs, color = 'red', alpha = 0.5, label = 'damaging')
    axs.set_title(title)
    axs.legend(loc='upper center')
    fig.savefig(title+'.pdf', bbox_inches='tight')
    #axs.set_xscale('log')
# Out:
# ../data/input_data.HIS.cnn.csv
# ../data/input_data.HS.cnn.csv
# ../data/case_control/case_MarkDaly.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv
# ../data/case_control/chd_yale.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv
# ../data/case_control/control_MarkDaly.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv
# ../data/case_control/DDD_new_0.2.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv
# ../data/case_control/case_MarkDaly.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv
# ../data/case_control/chd_yale.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv
# ../data/case_control/control_MarkDaly.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv
# ../data/case_control/DDD_new_0.2.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv
# ../data/cancer_hotspots/cancer_sel.HIS.reformat.cnn.csvAnn.mpc.csv
# ../data/cancer_hotspots/cancer_sel.HS.reformat.cnn.csvAnn.mpc.csv
# ../data/metaSVM/metaSVM_addtest1.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv
# ../data/metaSVM/metaSVM_addtest1.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv
# ../data/metaSVM/metaSVM_addtest2.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv
# ../data/metaSVM/metaSVM_addtest2.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv
# ../data/metaSVM/metaSVM_test1.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv
# ../data/metaSVM/metaSVM_test1.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv
# ../data/metaSVM/metaSVM_test2.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv
# ../data/metaSVM/metaSVM_test2.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv
# ../data/metaSVM/metaSVM_test3.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv
# ../data/metaSVM/metaSVM_test3.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv
# ../data/metaSVM/metaSVM_train.anno.rare.HIS.reformat.cnn.csvAnn.mpc.csv
# ../data/metaSVM/metaSVM_train.anno.rare.HS.reformat.cnn.csvAnn.mpc.csv

# %%
fins = ['../data/case_control/case.anno.rare.HIS.reformat.cnn.csv',
        '../data/case_control/case.anno.rare.HS.reformat.cnn.csv']



col = 'cnn_prob'#'cnn_prob' #'pli'
for fin in fins:
    print fin
    
    df = pd.read_csv(fin)
    title = fin.split('/')[-1].split('.')[0]

    
    df_pos = df[df.target==1]
    df_pos = df[df.disease=='ASD']
    if '.HIS.' in fin:
        title = 'HIS-ASD\npos:{}'.format(df_pos.shape[0])
    elif '.HS.' in fin:
        title = 'HS-ASD\npos:{}'.format(df_pos.shape[0])
    
    
    fig, axs = plt.subplots()
    df_pos.hist(col, bins = 100, ax = axs, color = 'red', alpha = 0.5, label = 'hotspot')
    axs.set_title(title)
    axs.legend(loc='upper left')
    fig.savefig(title+'.pdf', bbox_inches='tight')
    #axs.set_xscale('log')
# Out:
# ../data/case_control/case.anno.rare.HIS.reformat.cnn.csv
# ../data/case_control/case.anno.rare.HS.reformat.cnn.csv

# %%
fins = ['../data/cancer_hotspots/cancer_sel.HIS.reformat.cnn.csvAnn.mpc.csv',
'../data/cancer_hotspots/cancer_sel.HS.reformat.cnn.csvAnn.mpc.csv']



col = 'cnn_prob'#'cnn_prob' #'pli'
for fin in fins:
    print fin
    
    df = pd.read_csv(fin)
    title = fin.split('/')[-1].split('.')[0]

    
    df_pos = df[df.target==1]
    if '.HIS.' in fin:
        title = 'HIS-' + title + '\npos:{}'.format(df_pos.shape[0])
    elif '.HS.' in fin:
        title = 'HS-' + title + '\npos:{}'.format(df_pos.shape[0])
    
    
    fig, axs = plt.subplots()
    df_pos.hist(col, bins = 100, ax = axs, color = 'red', alpha = 0.5, label = 'hotspot')
    axs.set_title(title)
    axs.legend(loc='upper left')
    fig.savefig('ASD'+ title+'.pdf', bbox_inches='tight')
    #axs.set_xscale('log')
# Out:
# ../data/cancer_hotspots/cancer_sel.HIS.reformat.cnn.csvAnn.mpc.csv
# ../data/cancer_hotspots/cancer_sel.HS.reformat.cnn.csvAnn.mpc.csv

# %% [markdown]
# # hgmd overlap with uniprot? there are 5800 overlap

# %%
def all_variants(fin):
    with open(fin, 'rU') as f:
        positive, negative = 0, 0
        r = csv.reader(f)
        head = r.next()
        res = set()
        for line in r:
            info = dict(zip(head, line))
            var_id = '_'.join([info['hg19_chr'], info['hg19_pos(1-based)'], info['ref'], info['alt']])
            res.add(var_id)
    return res
            

# HGMD positive training
fin = '../data/training/HGMD_DM_missense_anno.rare.csv' 
hgmd_variants = all_variants(fin)

# Discover negative data
fin = '../data/training/DiscovEHR_rare_missense_30000.csv' 
dis_variants = all_variants(fin)

# metaSVM training 
fin = '../data/training/metaSVM_train.anno.rare.csv' 
uniprot_variants = all_variants(fin)

# %%
len(hgmd_variants & uniprot_variants)
# Out:
# 5829

# %% [markdown]
# # all mvp dist

# %%
import numpy as np
pli = np.load('../data/gene/pli.npy').item()
HS_gene = set(gene for gene, pli_score in pli.iteritems() if pli_score < 0.5)
HIS_gene = set(gene for gene, pli_score in pli.iteritems() if pli_score >= 0.5)

# %%
mvp_hs, mvp_his = [], []
fname = '/data/hq2130/large_files/All_rare_missense0624.txt'
with open(fname) as f:
    head = f.readline().strip().split()
    for line in f:
        lst = line.strip().split()
        if lst[-2] in HIS_gene:
            mvp_his.append(float(lst[-1]))
        if lst[-2] in HS_gene:
            mvp_hs.append(float(lst[-1]))

# %%
fig = plt.figure(figsize=(8,8))




n, bins, patches = plt.hist(mvp_hs, 40)

# # add a 'best fit' line
# y = mlab.normpdf( bins, mu, sigma)
# l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('mvp score')
plt.ylabel('# variants')
plt.title('mvp dist among all missense variants in HS genes')
fig.savefig("mvp dist among all missense variants in HS genes.pdf", bbox_inches='tight')

# %%
# calculate missing rate

# %%
fins = ['../data/case_control/case.anno.rare.csv', 
        '../data/case_control/DDD_new_0.2.anno.rare.csv',
        '../data/case_control/chd_yale.anno.rare.csv',
        '../data/case_control/case_MarkDaly.anno.rare.csv',
        '../data/case_control/control_MarkDaly.anno.rare.csv']

ret = []
names = []

    
for fin in fins:
    df = pd.read_csv(fin)
    tmp = df[~df.aaalt.isin(['.', 'X'])]
    tmp = tmp[~tmp.aaref.isin(['U'])]
    missing_rate = (tmp.astype(str) == '.').sum() / tmp.shape[0]
    names.append(fin.split('/')[-1])
    ret.append(missing_rate)
tab=pd.concat(ret, 1, keys = names)   
tab.to_csv('../data/training/missing_value_noREVEL_MPC.csv', sep='\t')

# %%
fins = ['../data/case_control/case.anno.rare.csv', 
        '../data/case_control/DDD_new_0.2.anno.rare.csv',
        '../data/case_control/chd_yale.anno.rare.csv',
        '../data/case_control/case_MarkDaly.anno.rare.csv',
        '../data/case_control/control_MarkDaly.anno.rare.csv']

for fin in fins:
    df = pd.read_csv(fin)
    #print df.head()
    #df
    #df.head()
    #df[:50]
    tmp = df[df['aaref'].isin(['U'])]
    print tmp
# Out:
# Empty DataFrame
# Columns: [hg19_chr, hg19_pos(1-based), ref, alt, aaref, aaalt, genename, refcodon, codonpos, aapos, 1000Gp3_AF, ExAC_AF, CADD_phred, Eigen-phred, Eigen-PC-phred, RVIS, Gene damage prediction (all disease-causing genes), Gene damage prediction (all Mendelian disease-causing genes), SIFT_converted_rankscore, Polyphen2_HDIV_rankscore, Polyphen2_HVAR_rankscore, LRT_converted_rankscore, MutationTaster_converted_rankscore, MutationAssessor_score_rankscore, FATHMM_converted_rankscore, PROVEAN_converted_rankscore, VEST3_rankscore, MetaSVM_rankscore, MetaLR_rankscore, M-CAP_rankscore, CADD_raw_rankscore, DANN_rankscore, fathmm-MKL_coding_rankscore, Eigen-PC-raw_rankscore, GenoCanyon_score_rankscore, integrated_fitCons_score_rankscore, GM12878_fitCons_score_rankscore, H1-hESC_fitCons_score_rankscore, HUVEC_fitCons_score_rankscore, GERP++_RS_rankscore, phyloP100way_vertebrate_rankscore, phyloP20way_mammalian_rankscore, phastCons100way_vertebrate_rankscore, phastCons20way_mammalian_rankscore, SiPhy_29way_logOdds_rankscore, INFO, disease, genename.1]
# Index: []
#
# [0 rows x 48 columns]
# Empty DataFrame
# Columns: [hg19_chr, hg19_pos(1-based), ref, alt, aaref, aaalt, genename, refcodon, codonpos, aapos, 1000Gp3_AF, ExAC_AF, CADD_phred, Eigen-phred, Eigen-PC-phred, RVIS, Gene damage prediction (all disease-causing genes), Gene damage prediction (all Mendelian disease-causing genes), SIFT_converted_rankscore, Polyphen2_HDIV_rankscore, Polyphen2_HVAR_rankscore, LRT_converted_rankscore, MutationTaster_converted_rankscore, MutationAssessor_score_rankscore, FATHMM_converted_rankscore, PROVEAN_converted_rankscore, VEST3_rankscore, MetaSVM_rankscore, MetaLR_rankscore, M-CAP_rankscore, CADD_raw_rankscore, DANN_rankscore, fathmm-MKL_coding_rankscore, Eigen-PC-raw_rankscore, GenoCanyon_score_rankscore, integrated_fitCons_score_rankscore, GM12878_fitCons_score_rankscore, H1-hESC_fitCons_score_rankscore, HUVEC_fitCons_score_rankscore, GERP++_RS_rankscore, phyloP100way_vertebrate_rankscore, phyloP20way_mammalian_rankscore, phastCons100way_vertebrate_rankscore, phastCons20way_mammalian_rankscore, SiPhy_29way_logOdds_rankscore, genename.1]
# Index: []
#
# [0 rows x 46 columns]
# Empty DataFrame
# Columns: [hg19_chr, hg19_pos(1-based), ref, alt, aaref, aaalt, genename, refcodon, codonpos, aapos, 1000Gp3_AF, ExAC_AF, CADD_phred, Eigen-phred, Eigen-PC-phred, RVIS, Gene damage prediction (all disease-causing genes), Gene damage prediction (all Mendelian disease-causing genes), SIFT_converted_rankscore, Polyphen2_HDIV_rankscore, Polyphen2_HVAR_rankscore, LRT_converted_rankscore, MutationTaster_converted_rankscore, MutationAssessor_score_rankscore, FATHMM_converted_rankscore, PROVEAN_converted_rankscore, VEST3_rankscore, MetaSVM_rankscore, MetaLR_rankscore, M-CAP_rankscore, CADD_raw_rankscore, DANN_rankscore, fathmm-MKL_coding_rankscore, Eigen-PC-raw_rankscore, GenoCanyon_score_rankscore, integrated_fitCons_score_rankscore, GM12878_fitCons_score_rankscore, H1-hESC_fitCons_score_rankscore, HUVEC_fitCons_score_rankscore, GERP++_RS_rankscore, phyloP100way_vertebrate_rankscore, phyloP20way_mammalian_rankscore, phastCons100way_vertebrate_rankscore, phastCons20way_mammalian_rankscore, SiPhy_29way_logOdds_rankscore, INFO, genename.1, disease]
# Index: []
#
# [0 rows x 48 columns]
# Empty DataFrame
# Columns: [hg19_chr, hg19_pos(1-based), ref, alt, aaref, aaalt, genename, refcodon, codonpos, aapos, 1000Gp3_AF, ExAC_AF, CADD_phred, Eigen-phred, Eigen-PC-phred, RVIS, Gene damage prediction (all disease-causing genes), Gene damage prediction (all Mendelian disease-causing genes), SIFT_converted_rankscore, Polyphen2_HDIV_rankscore, Polyphen2_HVAR_rankscore, LRT_converted_rankscore, MutationTaster_converted_rankscore, MutationAssessor_score_rankscore, FATHMM_converted_rankscore, PROVEAN_converted_rankscore, VEST3_rankscore, MetaSVM_rankscore, MetaLR_rankscore, M-CAP_rankscore, CADD_raw_rankscore, DANN_rankscore, fathmm-MKL_coding_rankscore, Eigen-PC-raw_rankscore, GenoCanyon_score_rankscore, integrated_fitCons_score_rankscore, GM12878_fitCons_score_rankscore, H1-hESC_fitCons_score_rankscore, HUVEC_fitCons_score_rankscore, GERP++_RS_rankscore, phyloP100way_vertebrate_rankscore, phyloP20way_mammalian_rankscore, phastCons100way_vertebrate_rankscore, phastCons20way_mammalian_rankscore, SiPhy_29way_logOdds_rankscore, disease, genename.1]
# Index: []
#
# [0 rows x 47 columns]
# Empty DataFrame
# Columns: [hg19_chr, hg19_pos(1-based), ref, alt, aaref, aaalt, genename, refcodon, codonpos, aapos, 1000Gp3_AF, ExAC_AF, CADD_phred, Eigen-phred, Eigen-PC-phred, RVIS, Gene damage prediction (all disease-causing genes), Gene damage prediction (all Mendelian disease-causing genes), SIFT_converted_rankscore, Polyphen2_HDIV_rankscore, Polyphen2_HVAR_rankscore, LRT_converted_rankscore, MutationTaster_converted_rankscore, MutationAssessor_score_rankscore, FATHMM_converted_rankscore, PROVEAN_converted_rankscore, VEST3_rankscore, MetaSVM_rankscore, MetaLR_rankscore, M-CAP_rankscore, CADD_raw_rankscore, DANN_rankscore, fathmm-MKL_coding_rankscore, Eigen-PC-raw_rankscore, GenoCanyon_score_rankscore, integrated_fitCons_score_rankscore, GM12878_fitCons_score_rankscore, H1-hESC_fitCons_score_rankscore, HUVEC_fitCons_score_rankscore, GERP++_RS_rankscore, phyloP100way_vertebrate_rankscore, phyloP20way_mammalian_rankscore, phastCons100way_vertebrate_rankscore, phastCons20way_mammalian_rankscore, SiPhy_29way_logOdds_rankscore, disease, genename.1]
# Index: []
#
# [0 rows x 47 columns]

# %%
fins = ['../data/case_control/case.anno.rare.HIS.reformat.GCcorrected.cnn.csv', 
        '../data/case_control/case.anno.rare.HS.reformat.GCcorrected.cnn.csv',
        '../data/case_control/case_MarkDaly.anno.rare.HIS.reformat.GCcorrected.cnn.csv',
        '../data/case_control/case_MarkDaly.anno.rare.HS.reformat.GCcorrected.cnn.csv',
        '../data/case_control/chd_yale.anno.rare.HIS.reformat.GCcorrected.cnn.csv',
        '../data/case_control/chd_yale.anno.rare.HS.reformat.GCcorrected.cnn.csv',
        '../data/case_control/DDD_new_0.2.anno.rare.HIS.reformat.GCcorrected.cnn.csv',
        '../data/case_control/DDD_new_0.2.anno.rare.HS.reformat.GCcorrected.cnn.csv',
        '../data/case_control/control_MarkDaly.anno.rare.HIS.reformat.GCcorrected.cnn.csv',
        '../data/case_control/control_MarkDaly.anno.rare.HS.reformat.GCcorrected.cnn.csv']

ret = []
names = []

    
for fin in fins:
    df = pd.read_csv(fin)
    tmp = df[~df.aaalt.isin(['.', 'X'])]
    tmp = tmp[~tmp.aaref.isin(['U'])]
    missing_rate = (tmp.astype(str) == '.').sum() / tmp.shape[0]
    names.append(fin.split('/')[-1])
    ret.append(missing_rate)
table = pd.concat(ret, 1, keys = names)
table.to_csv('../data/training/missing_value.csv', sep='\t')
